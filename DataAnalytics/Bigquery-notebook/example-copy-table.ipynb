# %%
from google.cloud import bigquery
from google.cloud.exceptions import NotFound
from google.oauth2 import service_account

# %%
def bq_create_dataset(client, dataset):
    dataset_ref = bigquery_client.dataset(dataset)
    
    try:
        dataset = bigquery_client.get_dataset(dataset_ref)
        print(f"Dataset {dataset} already exists.")
    except NotFound:
        dataset = bigquery.Dataset(dataset_ref)
        dataset.location = 'US'
        dataset = bigquery_client.create_dataset(dataset)
        print(f"Dataset {dataset.dataset_id} created.")
    return dataset

def bq_create_table(client, dataset, table_name):
    dataset_ref = bigquery_client.dataset(dataset)
    
    # Prepare a referece to the table
    table_ref = dataset_ref.table(table_name)
    
    try:
        table = bigquery_client.get_table(table_ref)
        print(f"table {table} already exists.")
    except NotFound:
        schema = [
            bigquery.SchemaField('S_No', 'INTEGER', mode='REQUIRED'),
            bigquery.SchemaField('Age_in_cm', 'INTEGER', mode='REQUIRED'),
            bigquery.SchemaField('Weight_in_Kg', 'INTEGER', mode='REQUIRED')
        ]
        table = bigquery.Table(table_ref, schema=schema)
        table = bigquery_client.create_table(table)
        print(f"table {table.table_id} created.")
    return table

key_path = './service_account/gentle-keyword-423715-j0-03be08ad6412.json'
credentials = service_account.Credentials.from_service_account_file(
    key_path,
    scopes=["https://www.googleapis.com/auth/bigquery"]
)
    
bigquery_client = bigquery.Client(
    credentials = credentials,
    project=credentials.project_id
)
if __name__ == '__main__':
    dataset = 'demo_dataset01'
    table_name = 'demo_table01'
    data = bq_create_dataset(bigquery_client, dataset)
    table = bq_create_table(bigquery_client, dataset, table_name)
# Out:
# Dataset Dataset(DatasetReference('gentle-keyword-423715-j0', 'demo_dataset01')) already exists.
# table demo_table01 created.

# %%
dataset_ref = bigquery_client.dataset('google_analytics_sample')
table_ref = dataset_ref.table('ga_sessions_20170801')

example = bigquery_client.get_table(table_ref)
example.schema
# Out:
# [SchemaField('visitorId', 'INTEGER', 'NULLABLE', None, None, (), None),
#  SchemaField('visitNumber', 'INTEGER', 'NULLABLE', None, None, (), None),
#  SchemaField('visitId', 'INTEGER', 'NULLABLE', None, None, (), None),
#  SchemaField('visitStartTime', 'INTEGER', 'NULLABLE', None, None, (), None),
#  SchemaField('date', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('totals', 'RECORD', 'NULLABLE', None, None, (SchemaField('visits', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('hits', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('pageviews', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('timeOnSite', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('bounces', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('transactions', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('transactionRevenue', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('newVisits', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('screenviews', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('uniqueScreenviews', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('timeOnScreen', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('totalTransactionRevenue', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('sessionQualityDim', 'INTEGER', 'NULLABLE', None, None, (), None)), None),
#  SchemaField('trafficSource', 'RECORD', 'NULLABLE', None, None, (SchemaField('referralPath', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('campaign', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('source', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('medium', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('keyword', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('adContent', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('adwordsClickInfo', 'RECORD', 'NULLABLE', None, None, (SchemaField('campaignId', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('adGroupId', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('creativeId', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('criteriaId', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('page', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('slot', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('criteriaParameters', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('gclId', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('customerId', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('adNetworkType', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('targetingCriteria', 'RECORD', 'NULLABLE', None, None, (SchemaField('boomUserlistId', 'INTEGER', 'NULLABLE', None, None, (), None),), None), SchemaField('isVideoAd', 'BOOLEAN', 'NULLABLE', None, None, (), None)), None), SchemaField('isTrueDirect', 'BOOLEAN', 'NULLABLE', None, None, (), None), SchemaField('campaignCode', 'STRING', 'NULLABLE', None, None, (), None)), None),
#  SchemaField('device', 'RECORD', 'NULLABLE', None, None, (SchemaField('browser', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('browserVersion', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('browserSize', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('operatingSystem', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('operatingSystemVersion', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('isMobile', 'BOOLEAN', 'NULLABLE', None, None, (), None), SchemaField('mobileDeviceBranding', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('mobileDeviceModel', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('mobileInputSelector', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('mobileDeviceInfo', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('mobileDeviceMarketingName', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('flashVersion', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('javaEnabled', 'BOOLEAN', 'NULLABLE', None, None, (), None), SchemaField('language', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('screenColors', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('screenResolution', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('deviceCategory', 'STRING', 'NULLABLE', None, None, (), None)), None),
#  SchemaField('geoNetwork', 'RECORD', 'NULLABLE', None, None, (SchemaField('continent', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('subContinent', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('country', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('region', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('metro', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('city', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('cityId', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('networkDomain', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('latitude', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('longitude', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('networkLocation', 'STRING', 'NULLABLE', None, None, (), None)), None),
#  SchemaField('customDimensions', 'RECORD', 'REPEATED', None, None, (SchemaField('index', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('value', 'STRING', 'NULLABLE', None, None, (), None)), None),
#  SchemaField('hits', 'RECORD', 'REPEATED', None, None, (SchemaField('hitNumber', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('time', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('hour', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('minute', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('isSecure', 'BOOLEAN', 'NULLABLE', None, None, (), None), SchemaField('isInteraction', 'BOOLEAN', 'NULLABLE', None, None, (), None), SchemaField('isEntrance', 'BOOLEAN', 'NULLABLE', None, None, (), None), SchemaField('isExit', 'BOOLEAN', 'NULLABLE', None, None, (), None), SchemaField('referer', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('page', 'RECORD', 'NULLABLE', None, None, (SchemaField('pagePath', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('hostname', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('pageTitle', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('searchKeyword', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('searchCategory', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('pagePathLevel1', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('pagePathLevel2', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('pagePathLevel3', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('pagePathLevel4', 'STRING', 'NULLABLE', None, None, (), None)), None), SchemaField('transaction', 'RECORD', 'NULLABLE', None, None, (SchemaField('transactionId', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('transactionRevenue', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('transactionTax', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('transactionShipping', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('affiliation', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('currencyCode', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('localTransactionRevenue', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('localTransactionTax', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('localTransactionShipping', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('transactionCoupon', 'STRING', 'NULLABLE', None, None, (), None)), None), SchemaField('item', 'RECORD', 'NULLABLE', None, None, (SchemaField('transactionId', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('productName', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('productCategory', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('productSku', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('itemQuantity', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('itemRevenue', 'INTEGER', 'NULLABLE', None, None, (), None), SchemaField('currencyCode', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('localItemRevenue', 'INTEGER', 'NULLABLE', None, None, (), None)), None), SchemaField('contentInfo', 'RECORD', 'NULLABLE', None, None, (SchemaField('contentDescription', 'STRING', 'NULLABLE', None, None, (), None),), None), SchemaField('appInfo', 'RECORD', 'NULLABLE', None, None, (SchemaField('name', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('version', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('id', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('installerId', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('appInstallerId', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('appName', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('appVersion', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('appId', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('screenName', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('landingScreenName', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('exitScreenName', 'STRING', 'NULLABLE', None, None, (), None), SchemaField('screenDepth', 'STRING', 'NULLABLE', None, None, (), None)), None), SchemaField('exceptionInfo', ' ...
#  SchemaField('fullVisitorId', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('userId', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('clientId', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('channelGrouping', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('socialEngagementType', 'STRING', 'NULLABLE', None, None, (), None)]

# %%
schema = [
            bigquery.SchemaField('S_No', 'INTEGER', mode='REQUIRED'),
            bigquery.SchemaField('Age_in_cm', 'INTEGER', mode='REQUIRED'),
            bigquery.SchemaField('Weight_in_Kg', 'INTEGER', mode='REQUIRED')
        ]

print(schema)
# Out:
# [SchemaField('S_No', 'INTEGER', 'REQUIRED', None, None, (), None), SchemaField('Age_in_cm', 'INTEGER', 'REQUIRED', None, None, (), None), SchemaField('Weight_in_Kg', 'INTEGER', 'REQUIRED', None, None, (), None)]

# %%
from datetime import datetime, timedelta

# Define the start and end dates
start_date = datetime.strptime('20160801', '%Y%m%d')
end_date = datetime.strptime('20170801', '%Y%m%d')

# Generate a list of dates in the specified range
date_list = []
current_date = start_date
while current_date <= end_date:
    date_list.append(current_date.strftime('%Y%m%d'))
    current_date += timedelta(days=1)

# Print the list of dates
for date in date_list:
    print(date)
# Out:
# 20160801
# 20160802
# 20160803
# 20160804
# 20160805
# 20160806
# 20160807
# 20160808
# 20160809
# 20160810
# 20160811
# 20160812
# 20160813
# 20160814
# 20160815
# 20160816
# 20160817
# 20160818
# 20160819
# 20160820
# 20160821
# 20160822
# 20160823
# 20160824
# 20160825
# 20160826
# 20160827
# 20160828
# 20160829
# 20160830
# 20160831
# 20160901
# 20160902
# 20160903
# 20160904
# 20160905
# 20160906
# 20160907
# 20160908
# 20160909
# 20160910
# 20160911
# 20160912
# 20160913
# 20160914
# 20160915
# 20160916
# 20160917
# 20160918
# 20160919
# 20160920
# 20160921
# 20160922
# 20160923
# 20160924
# 20160925
# 20160926
# 20160927
# 20160928
# 20160929
# 20160930
# 20161001
# 20161002
# 20161003
# 20161004
# 20161005
# 20161006
# 20161007
# 20161008
# 20161009
# 20161010
# 20161011
# 20161012
# 20161013
# 20161014
# 20161015
# 20161016
# 20161017
# 20161018
# 20161019
# 20161020
# 20161021
# 20161022
# 20161023
# 20161024
# 20161025
# 20161026
# 20161027
# 20161028
# 20161029
# 20161030
# 20161031
# 20161101
# 20161102
# 20161103
# 20161104
# 20161105
# 20161106
# 20161107
# 20161108
# 20161109
# 20161110
# 20161111
# 20161112
# 20161113
# 20161114
# 20161115
# 20161116
# 20161117
# 20161118
# 20161119
# 20161120
# 20161121
# 20161122
# 20161123
# 20161124
# 20161125
# 20161126
# 20161127
# 20161128
# 20161129
# 20161130
# 20161201
# 20161202
# 20161203
# 20161204
# 20161205
# 20161206
# 20161207
# 20161208
# 20161209
# 20161210
# 20161211
# 20161212
# 20161213
# 20161214
# 20161215
# 20161216
# 20161217
# 20161218
# 20161219
# 20161220
# 20161221
# 20161222
# 20161223
# 20161224
# 20161225
# 20161226
# 20161227
# 20161228
# 20161229
# 20161230
# 20161231
# 20170101
# 20170102
# 20170103
# 20170104
# 20170105
# 20170106
# 20170107
# 20170108
# 20170109
    # Delete the existing destination table if it exists
    try:
        client.delete_table(destination_table_ref)
        print(f"Deleted table {destination_table_ref}")
    except Exception as e:
        print(f"Table {destination_table_ref} does not exist: {e}")


    # Create the destination table with the same schema as the source table
    destination_table = bigquery.Table(destination_table_ref, schema=schema)
    destination_table = client.create_table(destination_table)  # API request

    print(f"Created table {destination_table.project}.{destination_table.dataset_id}.{destination_table.table_id}")

    # Define the copy job configuration
    job_config = bigquery.CopyJobConfig()

    # Copy the table
    copy_job = client.copy_table(
        source_table_ref,
        destination_table_ref,
        job_config=job_config
    )  # Make an API request.

    # Wait for the job to complete
    copy_job.result()

    print(f"Table {source_table_ref} copied to {destination_table_ref}.")
# Out:
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170115 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170115?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170115
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170115
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170115 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170115.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170116 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170116?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170116
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170116
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170116 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170116.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170117 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170117?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170117
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170117
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170117 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170117.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170118 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170118?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170118
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170118
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170118 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170118.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170119 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170119?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170119
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170119
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170119 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170119.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170120 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170120?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170120
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170120
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170120 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170120.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170121 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170121?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170121
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170121
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170121 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170121.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170122 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170122?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170122
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170122
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170122 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170122.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170123 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170123?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170123
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170123
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170123 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170123.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170124 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170124?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170124
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170124
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170124 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170124.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170125 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170125?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170125
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170125
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170125 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170125.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170126 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170126?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170126
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170126
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170126 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170126.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170127 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170127?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170127
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170127
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170127 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170127.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170128 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170128?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170128
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170128
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170128 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170128.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170129 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170129?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170129
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170129
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170129 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170129.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170130 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170130?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170130
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170130
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170130 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170130.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170131 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170131?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170131
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170131
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170131 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170131.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170201 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170201?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170201
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170201
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170201 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170201.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170202 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170202?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170202
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170202
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170202 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170202.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170203 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170203?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170203
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170203
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170203 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170203.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170204 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170204?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170204
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170204
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170204 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170204.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170205 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170205?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170205
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170205
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170205 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170205.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170206 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170206?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170206
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170206
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170206 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170206.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170207 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170207?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170207
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170207
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170207 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170207.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170208 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170208?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170208
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170208
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170208 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170208.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170209 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170209?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170209
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170209
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170209 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170209.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170210 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170210?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170210
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170210
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170210 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170210.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170211 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170211?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170211
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170211
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170211 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170211.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170212 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170212?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170212
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170212
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170212 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170212.
# Table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170213 does not exist: 404 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/gentle-keyword-423715-j0/datasets/google_analytics_sample/tables/ga_sessions_20170213?prettyPrint=false: Not found: Table gentle-keyword-423715-j0:google_analytics_sample.ga_sessions_20170213
# Created table gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170213
# Table bigquery-public-data.google_analytics_sample.ga_sessions_20170213 copied to gentle-keyword-423715-j0.google_analytics_sample.ga_sessions_20170213.

# %%
date_list[167:197]
# Out:
# ['20170115',
#  '20170116',
#  '20170117',
#  '20170118',
#  '20170119',
#  '20170120',
#  '20170121',
#  '20170122',
#  '20170123',
#  '20170124',
#  '20170125',
#  '20170126',
#  '20170127',
#  '20170128',
#  '20170129',
#  '20170130',
#  '20170131',
#  '20170201',
#  '20170202',
#  '20170203',
#  '20170204',
#  '20170205',
#  '20170206',
#  '20170207',
#  '20170208',
#  '20170209',
#  '20170210',
#  '20170211',
#  '20170212',
#  '20170213']
