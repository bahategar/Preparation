# %%
from bs4 import BeautifulSoup
import requests

# %%
resp = requests.get("https://www.wayofwade.com/collections/basketball-shoes")

resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'<!doctype html><html class="t4sp-theme t4s-wrapper__full_width rtl_false swatch_color_style_2 pr_border_style_1 pr_img_effect_1 enable_eff_img1_true badge_shape_2 css_for_wis_app_false t4s-lzcus-true shadow_round_img_true t4s-header__inline is-remove-unavai-1 t4_compare_false is-catalog__mode-false t4s-cart-count-0 t4s-pr-ellipsis-false\n no-js" lang="en">\n  <head>\n    \n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1, height=device-height, minimum-scale=1.0, maximum-scale=1.0">\n    <meta name="theme-color" content="#333333">\n    <meta name="google-site-verification" content="9s3VMSit6y6YaP9wGi2IwbuMAA5uKlHX2ScgoGdGjnY" />\n    <meta name="description" content="Shop for the best selection of basketball shoes by Way of Wade to elevate your game. Buy the latest Dwyane Wade&#39;s Li-Ning &#39;s basketball/sports shoes online."><link rel="shortcut icon" type="image/png" hre
# ...
